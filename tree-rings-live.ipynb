# %%
# !git clone https://github.com/shreyjain711/tree-ring-watermark.git
# %cd "/kaggle/working/tree-ring-watermark"
# Out:
# Cloning into 'tree-ring-watermark'...
# remote: Enumerating objects: 335, done.
# remote: Counting objects: 100% (185/185), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 335 (delta 125), reused 154 (delta 109), pack-reused 150 (from 1)
# Receiving objects: 100% (335/335), 6.07 MiB | 24.08 MiB/s, done.
# Resolving deltas: 100% (177/177), done.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 82.1 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 75.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 30.3 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !pip install wandb scikit-learn ftfy datasets torch==2.1.0 torchvision==0.16.0 diffusers==0.12.1
# !pip install "jax[cuda]==0.4.23" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

import torch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 56.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 29.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.11.1
#     Uninstalling diffusers-0.11.1:
#       Successfully uninstalled diffusers-0.11.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.19.0
#     Uninstalling torchvision-0.19.0:
#       Successfully uninstalled torchvision-0.19.0
# ...
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 MB 13.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 6.8 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.26.dev20240620
# ...

# %%
# !git pull
# Out:
# Already up to date.

# %%
for r_deg in [0, 30, 45, 75, 90, 105, 180]:
    torch.cuda.empty_cache() 
    run_name = f"rotat_exp_{r_deg}"
    # !python run_tree_ring_watermark.py --run_name {run_name} --start 0 --end 1 --r_degree {r_deg} --w_channel 3 --num_inference_steps 50 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/wandb/run-20241126_171728-3vjm85uv
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rotat_exp_0
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/3vjm85uv
# ...
# 100%|███████████████████████████████████████████| 50/50 [00:08<00:00,  5.98it/s]
#
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 975 bytes | 975.00 KiB/s, done.
# From https://github.com/shreyjain711/tree-ring-watermark
#    36dff1c..d16aeea  main       -> origin/main
# Updating 36dff1c..d16aeea
# Fast-forward
#  optim_utils.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
for rsz in [0.05, 0.1, 0.25, 0.5, 0.6, 0.8, 1]:
    torch.cuda.empty_cache() 
    run_name = f"resize_{rsz}"
    # !python run_tree_ring_watermark.py --run_name {run_name} --start 0 --end 1 --crop_scale {rsz} --crop_ratio 1 --w_channel 3 --num_inference_steps 50 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/wandb/run-20241126_180122-biee9jnf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run resize_0.05
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/biee9jnf
# ...
# 100%|███████████████████████████████████████████| 50/50 [00:08<00:00,  5.90it/s]
#
# ...

# %%
# !python run_tree_ring_watermark.py --run_name rotat_exp --start 0 --end 1 --r_degree 45 --resizedcrop_factor 0.5 --w_channel 3 --num_inference_steps 50 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724

# %%
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 0 --end 1 --r_degree 30 --w_channel 3 --num_inference_steps 50 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/wandb/run-20241121_185516-93gk1yv0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MidTermExps
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/93gk1yv0
# ...

# %%
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 94 --end 95 --num_inference_steps 50 --r_degree 90 --with_tracking --w_radius_incr 1 --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 8 --end 9 --num_inference_steps 50 --r_degree 180 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 72 --end 73 --num_inference_steps 50 --jpeg_ratio 0.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 15 --end 16 --num_inference_steps 50 --gaussian_blur_r 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 7 --end 8 --num_inference_steps 50 --gaussian_std 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 57 --end 58 --num_inference_steps 50 --brightness_factor 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 64 --end 65 --num_inference_steps 50 --contrast_factor 1.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 65 --end 66 --num_inference_steps 50 --erasing_factor 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 24 --end 25 --num_inference_steps 50 --noise_factor 0.02 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 33 --end 34 --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/wandb/run-20241119_074013-gako2rjq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MidTermExps
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/gako2rjq
# ^C
# Traceback (most recent call last):
# ...

# %%
import numpy as np

i=0

num_inference_steps = [10, 25, 50, 100]
w_radius_s, w_radius_incrs = [10, 20, 30, 50, 100], [1, 2, 3, 5, 10]

# experiments = {
#     'r_degree': [15, 45, 60, 90, 135, 180],
#     'jpeg_ratio': [0.1, 0.2, 0.3, 0.5, 0.8],
#     'gaussian_blur_r': [1, 2, 3, 5, 10],
#     'gaussian_std': [0.05, 0.1, 0.2, 0.3, 0.5],
#     'brightness_factor': [0.5, 0.8, 1.2, 1.5, 2.0],
#     'contrast_factor': [1.1, 1.2, 1.5, 2.0],
#     'erasing_factor': [0.05, 0.1, 0.15, 0.2, 0.25],
#     'noise_factor': [0.01, 0.02, 0.05, 0.1],
#     'resizedcrop_factor': [0.5, 0.8, 1.0]
# }

experiments = {
    'r_degree': [90, 180],
    'jpeg_ratio': [0.2],
    'gaussian_blur_r': [2],
    'gaussian_std': [0.1],
    'brightness_factor': [0.8],
    'contrast_factor': [1.2],
    'erasing_factor': [0.1],
    'noise_factor': [0.02],
    'resizedcrop_factor': [0.5]
}

# %%
for perturb in experiments.keys():
    for value in experiments[perturb]:
        if perturb == 'resizedcrop_factor':
            for value_y in experiments[perturb]:
                i = np.random.randint(0, 100)
                print(f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --w_channel 3 --num_inference_steps 50 --{perturb}_x {value} --{perturb}_y {1} --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724')
        else:
            i = np.random.randint(0, 100)
            command = f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --w_channel 3 --num_inference_steps 50 --{perturb} {value} --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724'
            print(command)
# Out:
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 67 --end 68 --w_channel 3 --num_inference_steps 50 --r_degree 90 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 39 --end 40 --w_channel 3 --num_inference_steps 50 --r_degree 180 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 69 --end 70 --w_channel 3 --num_inference_steps 50 --jpeg_ratio 0.2 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# ...

# %%
# !python run_tree_ring_watermark.py --run_name Exp7 --start 21 --end 22 --w_channel 3 --num_inference_steps 50 --jpeg_ratio 2 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241105_032616-i3y45tza
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Exp7
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/i3y45tza
# ...

# %%
# !python run_tree_ring_watermark.py --run_name w_channel_0 --start 92 --end 93 --w_channel 0 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name w_channel_1 --start 92 --end 93 --w_channel 1 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name w_channel_2 --start 92 --end 93 --w_channel 2 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name w_channel_3 --start 92 --end 93 --w_channel 3 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name w_channel_m1 --start 92 --end 93 --w_channel -1 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241115_180318-xo3ud4l5
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run w_channel_m1
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# ...

# %%
# !python run_tree_ring_watermark.py --run_name square_c3 --start 18 --end 19 --w_channel 3 --w_mask_shape square --num_inference_steps 50 --w_radius 10 --r_degree 45 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241121_162036-18ip10ys
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run square_c3
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# ...

# %%
for wc in [-1, 0, 1, 2, 3]:
    isWcM1 = ('m' if wc==-1 else '')
    run_name = f'w_channel_{isWcM1}{abs(wc)}'
    # !python run_tree_ring_watermark.py --run_name {run_name} --start 18 --end 19 --w_channel {wc} --num_inference_steps 50 --r_degree 30 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241115_194450-7o4tu7k9
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run w_channel_m1
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/7o4tu7k9
# ...

# %%
for wc in [-1, 0, 1, 2, 3]:
    isWcM1 = ('m' if wc==-1 else '')
    run_name = f'w_channel_{isWcM1}{abs(wc)}'
    # !python run_tree_ring_watermark.py --run_name {run_name} --start 27 --end 28 --w_channel {wc} --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 1 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# Moving 0 files to the new cache system
# 0it [00:00, ?it/s]
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241115_181428-7n2r84fi
# ...

# %%
# !python run_tree_ring_watermark.py --run_name Exp1 --start 72 --end 73 --w_channel 3 --num_inference_steps 50 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp2 --start 79 --end 80 --w_channel 3 --num_inference_steps 10 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp3 --start 92 --end 93 --w_channel 3 --num_inference_steps 100 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp4 --start 72 --end 73 --w_channel 3 --num_inference_steps 50 --w_radius 20 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp5 --start 18 --end 19 --w_channel 3 --num_inference_steps 50 --r_degree 90 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp6 --start 72 --end 73 --w_channel 3 --num_inference_steps 50 --r_degree 180 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp7 --start 21 --end 22 --w_channel 3 --num_inference_steps 50 --jpeg_ratio 2 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp8 --start 4 --end 5 --w_channel 3 --num_inference_steps 50 --gaussian_blur_r 2 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp9 --start 98 --end 99 --w_channel 3 --num_inference_steps 50 --gaussian_std 0.1 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp10 --start 73 --end 74 --w_channel 3 --num_inference_steps 50 --brightness_factor 0.8 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp11 --start 34 --end 35 --w_channel 3 --num_inference_steps 50 --contrast_factor 1.2 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp12 --start 73 --end 74 --w_channel 3 --num_inference_steps 50 --erasing_factor 0.1 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp13 --start 95 --end 96 --w_channel 3 --num_inference_steps 50 --noise_factor 0.02 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name Exp14 --start 27 --end 28 --w_channel 3 --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 1 --w_radius 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241105_031104-0gj50wig
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run Exp1
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/0gj50wig
# ...

# %%
for nis in num_inference_steps:
    i = np.random.randint(0, 100)
    command = f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --num_inference_steps {nis} --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724'
    print(command)

for w_radius in w_radius_s:
    for w_radius_incr in w_radius_incrs:
        i = np.random.randint(0, 100)
        command = f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --w_radius {w_radius} --w_radius_incr {w_radius_incr} --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724'
        print(command)

for perturb in experiments.keys():
    for value in experiments[perturb]:
        if perturb == 'resizedcrop_factor':
            for value_y in experiments[perturb]:
                i = np.random.randint(0, 100)
                print(f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --num_inference_steps 50 --{perturb}_x {value} --{perturb}_y {value_y} --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724')
        else:
            i = np.random.randint(0, 100)
            command = f'!python run_tree_ring_watermark.py --run_name MidTermExps --start {i} --end {i+1} --num_inference_steps 50 --{perturb} {value} --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724'
            print(command)
# Out:
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 47 --end 48 --num_inference_steps 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 28 --end 29 --num_inference_steps 25 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 22 --end 23 --num_inference_steps 50 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# ...

# %%
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 47 --end 48 --num_inference_steps 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 28 --end 29 --num_inference_steps 25 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 22 --end 23 --num_inference_steps 50 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 63 --end 64 --num_inference_steps 100 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 50 --end 51 --w_radius 10 --w_radius_incr 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 3 --end 4 --w_radius 10 --w_radius_incr 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 80 --end 81 --w_radius 10 --w_radius_incr 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 80 --end 81 --w_radius 10 --w_radius_incr 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 24 --end 25 --w_radius 10 --w_radius_incr 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 90 --end 91 --w_radius 20 --w_radius_incr 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 75 --end 76 --w_radius 20 --w_radius_incr 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 67 --end 68 --w_radius 20 --w_radius_incr 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 95 --end 96 --w_radius 20 --w_radius_incr 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 13 --end 14 --w_radius 20 --w_radius_incr 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 5 --end 6 --w_radius 30 --w_radius_incr 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 2 --end 3 --w_radius 30 --w_radius_incr 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 4 --end 5 --w_radius 30 --w_radius_incr 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 3 --end 4 --w_radius 30 --w_radius_incr 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 7 --end 8 --w_radius 30 --w_radius_incr 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 76 --end 77 --w_radius 50 --w_radius_incr 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 1 --end 2 --w_radius 50 --w_radius_incr 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 16 --end 17 --w_radius 50 --w_radius_incr 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 91 --end 92 --w_radius 50 --w_radius_incr 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 86 --end 87 --w_radius 50 --w_radius_incr 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 4 --end 5 --w_radius 100 --w_radius_incr 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 51 --end 52 --w_radius 100 --w_radius_incr 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 97 --end 98 --w_radius 100 --w_radius_incr 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 15 --end 16 --w_radius 100 --w_radius_incr 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 10 --end 11 --w_radius 100 --w_radius_incr 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 59 --end 60 --num_inference_steps 50 --r_degree 15 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 41 --end 42 --num_inference_steps 50 --r_degree 45 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 39 --end 40 --num_inference_steps 50 --r_degree 60 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 64 --end 65 --num_inference_steps 50 --r_degree 90 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 48 --end 49 --num_inference_steps 50 --r_degree 135 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 58 --end 59 --num_inference_steps 50 --r_degree 180 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 37 --end 38 --num_inference_steps 50 --jpeg_ratio 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 67 --end 68 --num_inference_steps 50 --jpeg_ratio 0.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 89 --end 90 --num_inference_steps 50 --jpeg_ratio 0.3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 44 --end 45 --num_inference_steps 50 --jpeg_ratio 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 88 --end 89 --num_inference_steps 50 --jpeg_ratio 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 69 --end 70 --num_inference_steps 50 --gaussian_blur_r 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 34 --end 35 --num_inference_steps 50 --gaussian_blur_r 2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 64 --end 65 --num_inference_steps 50 --gaussian_blur_r 3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 22 --end 23 --num_inference_steps 50 --gaussian_blur_r 5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 94 --end 95 --num_inference_steps 50 --gaussian_blur_r 10 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 35 --end 36 --num_inference_steps 50 --gaussian_std 0.05 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 28 --end 29 --num_inference_steps 50 --gaussian_std 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 40 --end 41 --num_inference_steps 50 --gaussian_std 0.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 27 --end 28 --num_inference_steps 50 --gaussian_std 0.3 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 45 --end 46 --num_inference_steps 50 --gaussian_std 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 40 --end 41 --num_inference_steps 50 --brightness_factor 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 14 --end 15 --num_inference_steps 50 --brightness_factor 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 40 --end 41 --num_inference_steps 50 --brightness_factor 1.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 82 --end 83 --num_inference_steps 50 --brightness_factor 1.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 59 --end 60 --num_inference_steps 50 --brightness_factor 2.0 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 48 --end 49 --num_inference_steps 50 --contrast_factor 1.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 11 --end 12 --num_inference_steps 50 --contrast_factor 1.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 55 --end 56 --num_inference_steps 50 --contrast_factor 1.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 2 --end 3 --num_inference_steps 50 --contrast_factor 2.0 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 95 --end 96 --num_inference_steps 50 --erasing_factor 0.05 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 81 --end 82 --num_inference_steps 50 --erasing_factor 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 98 --end 99 --num_inference_steps 50 --erasing_factor 0.15 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 0 --end 1 --num_inference_steps 50 --erasing_factor 0.2 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 45 --end 46 --num_inference_steps 50 --erasing_factor 0.25 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 0 --end 1 --num_inference_steps 50 --noise_factor 0.01 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 44 --end 45 --num_inference_steps 50 --noise_factor 0.02 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 34 --end 35 --num_inference_steps 50 --noise_factor 0.05 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 65 --end 66 --num_inference_steps 50 --noise_factor 0.1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 34 --end 35 --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 22 --end 23 --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 64 --end 65 --num_inference_steps 50 --resizedcrop_factor_x 0.5 --resizedcrop_factor_y 1.0 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 53 --end 54 --num_inference_steps 50 --resizedcrop_factor_x 0.8 --resizedcrop_factor_y 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 8 --end 9 --num_inference_steps 50 --resizedcrop_factor_x 0.8 --resizedcrop_factor_y 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 56 --end 57 --num_inference_steps 50 --resizedcrop_factor_x 0.8 --resizedcrop_factor_y 1.0 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 79 --end 80 --num_inference_steps 50 --resizedcrop_factor_x 1.0 --resizedcrop_factor_y 0.5 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 95 --end 96 --num_inference_steps 50 --resizedcrop_factor_x 1.0 --resizedcrop_factor_y 0.8 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# !python run_tree_ring_watermark.py --run_name MidTermExps --start 43 --end 44 --num_inference_steps 50 --resizedcrop_factor_x 1.0 --resizedcrop_factor_y 1.0 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k --wandb_API_key c7d77f7080d30d032dcac5a88bc6e3ea18058724
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/tree-ring-watermark/wandb/run-20241105_001826-fqwhrv2p
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run MidTermExps
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/fqwhrv2p
# ...

# %%
# !python run_tree_ring_watermark.py --run_name ring_radius_exp --w_channel 3 --w_pattern ring --r_degree 90 --start 0 --end 2 --with_tracking
