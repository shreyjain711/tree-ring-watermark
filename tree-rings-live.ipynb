# %%
# !git clone https://github.com/shreyjain711/tree-ring-watermark.git
# %cd tree-ring-watermark
# Out:
# Cloning into 'tree-ring-watermark'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 212 (delta 44), reused 29 (delta 29), pack-reused 150 (from 1)
# Receiving objects: 100% (212/212), 6.03 MiB | 18.84 MiB/s, done.
# Resolving deltas: 100% (96/96), done.
# /kaggle/working/tree-ring-watermark

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB 859.3 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 6.4 MB/s eta 0:00:00:00:01:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 524.9/524.9 kB 3.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 59.5 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 45.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.9 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.0
#     Uninstalling tokenizers-0.20.0:
#       Successfully uninstalled tokenizers-0.20.0
# ...

# %%
# !pip install wandb scikit-learn torchvision ftfy datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.4 MB/s eta 0:00:00
# ...

# %%
pip install torch==2.1.0 torchvision==0.16.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 10.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 78.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 11.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !pip install diffusers==0.12.1
# !pip install "jax[cuda]==0.4.23" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.0/604.0 kB 23.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.11.1
#     Uninstalling diffusers-0.11.1:
#       Successfully uninstalled diffusers-0.11.1
# ...
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 MB 10.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.5 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.26.dev20240620
#     Uninstalling jaxlib-0.4.26.dev20240620:
#       Successfully uninstalled jaxlib-0.4.26.dev20240620
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.26
#     Uninstalling jax-0.4.26:
#       Successfully uninstalled jax-0.4.26
# ...

# %%
# !python run_tree_ring_watermark.py --run_name no_attack --w_channel 3 --w_pattern ring --start 0 --end 1 --with_tracking --reference_model ViT-g-14 --reference_model_pretrain laion2b_s12b_b42k
# Out:
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/tree-ring-watermark/run_tree_ring_watermark.py", line 10, in <module>
#     from inverse_stable_diffusion import InversableStableDiffusionPipeline
#   File "/kaggle/working/tree-ring-watermark/inverse_stable_diffusion.py", line 7, in <module>
#     from diffusers.models import AutoencoderKL, UNet2DConditionModel
#   File "/opt/conda/lib/python3.10/site-packages/diffusers/__init__.py", line 54, in <module>
#     from .pipelines import (
#   File "/opt/conda/lib/python3.10/site-packages/diffusers/pipelines/__init__.py", line 44, in <module>
#     from .alt_diffusion import AltDiffusionImg2ImgPipeline, AltDiffusionPipeline
#   File "/opt/conda/lib/python3.10/site-packages/diffusers/pipelines/alt_diffusion/__init__.py", line 33, in <module>
#     from .pipeline_alt_diffusion import AltDiffusionPipeline
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1005 bytes | 1005.00 KiB/s, done.
# From https://github.com/shreyjain711/tree-ring-watermark
#    ca58a60..6b346ea  main       -> origin/main
# Updating ca58a60..6b346ea
# Fast-forward
#  run_tree_ring_watermark.py | 5 ++++-
#  1 file changed, 4 insertions(+), 1 deletion(-)

# %%
for loop:
    # !python run_tree_ring_watermark.py --run_name rotation --w_channel 3 --w_pattern ring --r_degree 75 --start 0 --end 1 --with_tracking
# Out:
#   Cell In[1], line 1
#     for loop:
#             ^
# SyntaxError: invalid syntax

# %%
# !python run_tree_ring_watermark.py --run_name ring_radius_exp --w_channel 3 --w_pattern ring --r_degree 75 --start 0 --end 1 --with_tracking
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: shreyj (shreyj-cmu). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Tracking run with wandb version 0.18.3
# wandb: Run data is saved locally in /kaggle/working/tree-ring-watermark/wandb/run-20241027_210433-w4jb08xf
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run rotation
# wandb: ⭐️ View project at https://wandb.ai/shreyj-cmu/diffusion_watermark
# wandb: 🚀 View run at https://wandb.ai/shreyj-cmu/diffusion_watermark/runs/w4jb08xf
# ...
# 100%|███████████████████████████████████████████| 50/50 [00:08<00:00,  6.22it/s]
#
# ...
